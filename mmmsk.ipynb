# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('student-por.csv')

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data['sex'].value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
# Proportion of students sex
data['sex'].value_counts()/data.shape[0]
# Out:
# sex
# F    0.590139
# M    0.409861
# Name: count, dtype: float64

# %%
categorical_columns  = data.dtypes[data.dtypes == 'object'].index

# %% [markdown]
# ## Count , Proportion , Mode

# %%
for col in categorical_columns:
    print('Column :- ' , col)
    print(data[col].value_counts())
    print(f'Proportion of Each Category    ' , data[col].value_counts()/data[col].count() )
    # Mode is defined as the category having highest proportion 
    print(f'Mode of the column is :  ' , data[col].value_counts().index[0] )
# Out:
# Column :-  school
# school
# GP    423
# MS    226
# Name: count, dtype: int64
# Proportion of Each Category     school
# GP    0.651772
# MS    0.348228
# Name: count, dtype: float64
# Mode of the column is :   GP
# Column :-  sex
# sex
# F    383
# M    266
# Name: count, dtype: int64
# Proportion of Each Category     sex
# F    0.590139
# M    0.409861
# Name: count, dtype: float64
# Mode of the column is :   F
# Column :-  address
# address
# U    452
# R    197
# Name: count, dtype: int64
# Proportion of Each Category     address
# U    0.696456
# R    0.303544
# Name: count, dtype: float64
# Mode of the column is :   U
# Column :-  famsize
# famsize
# GT3    457
# LE3    192
# Name: count, dtype: int64
# Proportion of Each Category     famsize
# GT3    0.70416
# LE3    0.29584
# Name: count, dtype: float64
# Mode of the column is :   GT3
# Column :-  Pstatus
# Pstatus
# T    569
# A     80
# Name: count, dtype: int64
# Proportion of Each Category     Pstatus
# T    0.876733
# ...

# %% [markdown]
# ## Mean Median Mode

# %%
numerical_columns = data.dtypes[data.dtypes != 'object'].index

# %%
for col in numerical_columns:
    print('Column : ', col )
    print('Mean of the Column : ' , data[col].mean())
    print('Median of the column is : ',data[col].median())
# Out:
# Column :  age
# Mean of the Column :  16.7442218798151
# Median of the column is :  17.0
# Column :  Medu
# Mean of the Column :  2.514637904468413
# Median of the column is :  2.0
# Column :  Fedu
# Mean of the Column :  2.3066255778120186
# Median of the column is :  2.0
# Column :  traveltime
# Mean of the Column :  1.568567026194145
# Median of the column is :  1.0
# Column :  studytime
# Mean of the Column :  1.9306625577812018
# Median of the column is :  2.0
# Column :  failures
# Mean of the Column :  0.2218798151001541
# Median of the column is :  0.0
# Column :  famrel
# Mean of the Column :  3.930662557781202
# Median of the column is :  4.0
# Column :  freetime
# Mean of the Column :  3.180277349768875
# Median of the column is :  3.0
# Column :  goout
# Mean of the Column :  3.184899845916795
# Median of the column is :  3.0
# Column :  Dalc
# Mean of the Column :  1.50231124807396
# Median of the column is :  1.0
# Column :  Walc
# ...

# %% [markdown]
# ## Range , IQR , Variance , Standard Deviation , Coefficient of Variation , Z-Score , Skewness

# %%
for col in numerical_columns:
    print('Column : ', col)
    print('Range of the Column is  ' , data[col].max()-data[col].min())
    print('Inter Quantile Range of thge Column is  : ', data[col].quantile(0.75)-data[col].quantile(0.25))
    print('Variances of the Column is : ' , data[col].std()**2)
    print('Standard Deviation of thge Column is : ', data[col].std())
    print('Skewness of the Column is : ' , np.where(3*(data[col].mean()-data[col].median())/data[col].std()<0 , 'Left Skewed' , 'Right Skewed'))
    print('Coefficient of Variation of the Column is : ', data[col].std()/data[col].mean())
# Out:
# Column :  age
# Range of the Column is   7
# Inter Quantile Range of thge Column is  :  2.0
# Variances of the Column is :  1.4838593087180663
# Standard Deviation of thge Column is :  1.2181376394800656
# Skewness of the Column is :  Left Skewed
# Coefficient of Variation of the Column is :  0.07274973111461881
# Column :  Medu
# Range of the Column is   4
# Inter Quantile Range of thge Column is  :  2.0
# Variances of the Column is :  1.2872082405980712
# Standard Deviation of thge Column is :  1.134551999953317
# Skewness of the Column is :  Right Skewed
# Coefficient of Variation of the Column is :  0.4511790735108472
# Column :  Fedu
# Range of the Column is   4
# Inter Quantile Range of thge Column is  :  2.0
# Variances of the Column is :  1.2098480092830373
# Standard Deviation of thge Column is :  1.099930911140803
# Skewness of the Column is :  Right Skewed
# Coefficient of Variation of the Column is :  0.4768571551973154
# Column :  traveltime
# Range of the Column is   3
# ...

# %% [markdown]
# #### Skewness is defined as follows :
#
#     Left Skewed (or) Negitively Skewed :  if mean < median < mode
#
#     Symmetric : Mean = Median = Mode
#
#     Right Skewed (or) Positively Skewed : if mean > median > mode
#
# ##### From above we came to know that skewness is dependent on the relative positions of mean and median if mean < median {Left Skewed} or mean > Medoan {Right Skewed}

# %% [markdown]
# #### Calculation of Skewness
#
# Criteria - 1 :
#
#         Pearson's Coefficient of Skewness :
#                             sk = 3(mean - median)/standardDeviation
# Criteria - 2 :
#
#         Bowley's Coefficient of Skewness :
#                             sk = ((Q3-Q2)-(Q2-Q1))/((Q3-Q2)+(Q2-Q1))
